# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(city_data)
# Out:
# 694

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Get current weather description from city list
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description
                          })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | henties bay
# Processing Record 2 of Set 1 | fairbanks
# Processing Record 3 of Set 1 | ulaangom
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | hithadhoo
# Processing Record 6 of Set 1 | saravan
# Processing Record 7 of Set 1 | avarua
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | qaanaaq
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | chuy
# Processing Record 13 of Set 1 | astipalaia
# City not found. Skipping...
# Processing Record 14 of Set 1 | sola
# Processing Record 15 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | yenagoa
# Processing Record 18 of Set 1 | reyes
# Processing Record 19 of Set 1 | abha
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | leeton
# Processing Record 22 of Set 1 | kamenka
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | kodiak
# Processing Record 25 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 1 | alofi
# Processing Record 28 of Set 1 | cayenne
# Processing Record 29 of Set 1 | espanola
# Processing Record 30 of Set 1 | portland
# Processing Record 31 of Set 1 | coihaique
# Processing Record 32 of Set 1 | babu
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | barrow
# Processing Record 36 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 1 | kindu
# Processing Record 38 of Set 1 | menongue
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | xining
# Processing Record 41 of Set 1 | ribeira grande
# Processing Record 42 of Set 1 | vila franca do campo
# Processing Record 43 of Set 1 | bluff
# Processing Record 44 of Set 1 | carrick-on-suir
# Processing Record 45 of Set 1 | anisoc
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | atambua
# Processing Record 48 of Set 1 | pervomaysk
# Processing Record 49 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 1 | wulanhaote
# City not found. Skipping...
# Processing Record 1 of Set 2 | olafsvik
# Processing Record 2 of Set 2 | pinawa
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 5 of Set 2 | porbandar
# Processing Record 6 of Set 2 | hilo
# Processing Record 7 of Set 2 | tasiilaq
# Processing Record 8 of Set 2 | asyut
# Processing Record 9 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 2 | saint-philippe
# Processing Record 11 of Set 2 | batemans bay
# Processing Record 12 of Set 2 | tuatapere
# Processing Record 13 of Set 2 | lahat
# Processing Record 14 of Set 2 | ancud
# Processing Record 15 of Set 2 | pitimbu
# Processing Record 16 of Set 2 | bosaso
# Processing Record 17 of Set 2 | dikson
# Processing Record 18 of Set 2 | narsaq
# Processing Record 19 of Set 2 | punta arenas
# Processing Record 20 of Set 2 | lompoc
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | cidreira
# Processing Record 23 of Set 2 | busselton
# Processing Record 24 of Set 2 | new norfolk
# Processing Record 25 of Set 2 | liverpool
# Processing Record 26 of Set 2 | pierre
# Processing Record 27 of Set 2 | weligama
# Processing Record 28 of Set 2 | formoso do araguaia
# City not found. Skipping...
# Processing Record 29 of Set 2 | puerto narino
# Processing Record 30 of Set 2 | severo-kurilsk
# Processing Record 31 of Set 2 | cabo san lucas
# Processing Record 32 of Set 2 | ust-kuyga
# Processing Record 33 of Set 2 | mount gambier
# Processing Record 34 of Set 2 | mahebourg
# Processing Record 35 of Set 2 | penzance
# Processing Record 36 of Set 2 | mar del plata
# Processing Record 37 of Set 2 | nikolskoye
# Processing Record 38 of Set 2 | bajil
# Processing Record 39 of Set 2 | north battleford
# Processing Record 40 of Set 2 | isla mujeres
# Processing Record 41 of Set 2 | adrar
# Processing Record 42 of Set 2 | puerto ayora
# Processing Record 43 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 2 | cockburn town
# Processing Record 45 of Set 2 | thompson
# Processing Record 46 of Set 2 | gannan
# Processing Record 47 of Set 2 | buenos aires
# Processing Record 48 of Set 2 | airai
# Processing Record 49 of Set 2 | sedelnikovo
# City not found. Skipping...
# Processing Record 50 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 3 | saskylakh
# Processing Record 2 of Set 3 | butaritari
# Processing Record 3 of Set 3 | sinnamary
# Processing Record 4 of Set 3 | port elizabeth
# Processing Record 5 of Set 3 | arrifes
# Processing Record 6 of Set 3 | esik
# Processing Record 7 of Set 3 | talnakh
# Processing Record 8 of Set 3 | owando
# Processing Record 9 of Set 3 | sur
# Processing Record 10 of Set 3 | beisfjord
# Processing Record 11 of Set 3 | arraial do cabo
# Processing Record 12 of Set 3 | hermanus
# Processing Record 13 of Set 3 | warrnambool
# Processing Record 14 of Set 3 | provideniya
# Processing Record 15 of Set 3 | ponta do sol
# Processing Record 16 of Set 3 | linjiang
# Processing Record 17 of Set 3 | souillac
# Processing Record 18 of Set 3 | puerto escondido
# Processing Record 19 of Set 3 | masumbwe
# Processing Record 20 of Set 3 | san quintin
# Processing Record 21 of Set 3 | buraydah
# Processing Record 22 of Set 3 | peniche
# Processing Record 23 of Set 3 | acapulco
# Processing Record 24 of Set 3 | havelock
# Processing Record 25 of Set 3 | tiksi
# Processing Record 26 of Set 3 | puertollano
# Processing Record 27 of Set 3 | skibbereen
# Processing Record 28 of Set 3 | port keats
# Processing Record 29 of Set 3 | bagdarin
# Processing Record 30 of Set 3 | castro
# Processing Record 31 of Set 3 | kavieng
# Processing Record 32 of Set 3 | andenes
# Processing Record 33 of Set 3 | jacareacanga
# Processing Record 34 of Set 3 | araouane
# Processing Record 35 of Set 3 | lavrentiya
# Processing Record 36 of Set 3 | pangai
# Processing Record 37 of Set 3 | matamoros
# Processing Record 38 of Set 3 | khatanga
# Processing Record 39 of Set 3 | kruisfontein
# Processing Record 40 of Set 3 | port-gentil
# Processing Record 41 of Set 3 | pozoblanco
# Processing Record 42 of Set 3 | hambantota
# Processing Record 43 of Set 3 | mahibadhoo
# Processing Record 44 of Set 3 | saint-pacome
# City not found. Skipping...
# Processing Record 45 of Set 3 | asosa
# Processing Record 46 of Set 3 | brae
# Processing Record 47 of Set 3 | grand bank
# Processing Record 48 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 3 | asekeyevo
# Processing Record 50 of Set 3 | iqaluit
# Processing Record 1 of Set 4 | conceicao do araguaia
# Processing Record 2 of Set 4 | cabedelo
# Processing Record 3 of Set 4 | palmer
# Processing Record 4 of Set 4 | muros
# Processing Record 5 of Set 4 | aklavik
# Processing Record 6 of Set 4 | vardo
# Processing Record 7 of Set 4 | puro
# Processing Record 8 of Set 4 | carnarvon
# Processing Record 9 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 4 | torbay
# Processing Record 11 of Set 4 | saint george
# Processing Record 12 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 4 | bredasdorp
# Processing Record 14 of Set 4 | leningradskiy
# Processing Record 15 of Set 4 | abong mbang
# Processing Record 16 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 4 | luanda
# Processing Record 18 of Set 4 | san fernando
# Processing Record 19 of Set 4 | east london
# Processing Record 20 of Set 4 | llanes
# Processing Record 21 of Set 4 | pelym
# Processing Record 22 of Set 4 | mount isa
# Processing Record 23 of Set 4 | sambava
# Processing Record 24 of Set 4 | ilulissat
# Processing Record 25 of Set 4 | galesong
# Processing Record 26 of Set 4 | bukachacha
# Processing Record 27 of Set 4 | upernavik
# Processing Record 28 of Set 4 | pangkalanbuun
# Processing Record 29 of Set 4 | asau
# Processing Record 30 of Set 4 | lagoa
# Processing Record 31 of Set 4 | goderich
# Processing Record 32 of Set 4 | santa rosa
# Processing Record 33 of Set 4 | kavaratti
# Processing Record 34 of Set 4 | starosubkhangulovo
# Processing Record 35 of Set 4 | bandarbeyla
# Processing Record 36 of Set 4 | piacabucu
# Processing Record 37 of Set 4 | colac
# Processing Record 38 of Set 4 | vilaka
# Processing Record 39 of Set 4 | sasebo
# Processing Record 40 of Set 4 | moron
# Processing Record 41 of Set 4 | kaitangata
# Processing Record 42 of Set 4 | clyde river
# Processing Record 43 of Set 4 | krasnyy chikoy
# Processing Record 44 of Set 4 | havoysund
# Processing Record 45 of Set 4 | kaeo
# Processing Record 46 of Set 4 | saldanha
# Processing Record 47 of Set 4 | mabaruma
# Processing Record 48 of Set 4 | esperance
# Processing Record 49 of Set 4 | leticia
# Processing Record 50 of Set 4 | chumikan
# Processing Record 1 of Set 5 | tagusao
# Processing Record 2 of Set 5 | bida
# Processing Record 3 of Set 5 | bilibino
# Processing Record 4 of Set 5 | chokurdakh
# Processing Record 5 of Set 5 | vilyuysk
# Processing Record 6 of Set 5 | bengkulu
# Processing Record 7 of Set 5 | surt
# Processing Record 8 of Set 5 | cedar city
# Processing Record 9 of Set 5 | khani
# Processing Record 10 of Set 5 | ulladulla
# Processing Record 11 of Set 5 | sorland
# Processing Record 12 of Set 5 | eureka
# Processing Record 13 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 5 | boende
# Processing Record 15 of Set 5 | bulawayo
# Processing Record 16 of Set 5 | sayat
# Processing Record 17 of Set 5 | paita
# Processing Record 18 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 5 | sioux lookout
# Processing Record 20 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 21 of Set 5 | nizwa
# Processing Record 22 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 23 of Set 5 | milkovo
# Processing Record 24 of Set 5 | tuktoyaktuk
# Processing Record 25 of Set 5 | georgetown
# Processing Record 26 of Set 5 | bethel
# Processing Record 27 of Set 5 | fort-shevchenko
# Processing Record 28 of Set 5 | padang
# Processing Record 29 of Set 5 | husavik
# Processing Record 30 of Set 5 | jining
# Processing Record 31 of Set 5 | launceston
# Processing Record 32 of Set 5 | almetyevsk
# Processing Record 33 of Set 5 | port lincoln
# Processing Record 34 of Set 5 | severo-yeniseyskiy
# Processing Record 35 of Set 5 | neath
# Processing Record 36 of Set 5 | teya
# Processing Record 37 of Set 5 | samarai
# Processing Record 38 of Set 5 | sol-iletsk
# Processing Record 39 of Set 5 | sao filipe
# Processing Record 40 of Set 5 | shingu
# Processing Record 41 of Set 5 | golden
# Processing Record 42 of Set 5 | bondo
# Processing Record 43 of Set 5 | raudeberg
# Processing Record 44 of Set 5 | la ronge
# Processing Record 45 of Set 5 | mujiayingzi
# Processing Record 46 of Set 5 | mamallapuram
# Processing Record 47 of Set 5 | hammerfest
# Processing Record 48 of Set 5 | saint anthony
# Processing Record 49 of Set 5 | san cristobal
# Processing Record 50 of Set 5 | ketchikan
# Processing Record 1 of Set 6 | okha
# Processing Record 2 of Set 6 | caravelas
# Processing Record 3 of Set 6 | careiro da varzea
# Processing Record 4 of Set 6 | pevek
# Processing Record 5 of Set 6 | esmeraldas
# Processing Record 6 of Set 6 | alta floresta
# Processing Record 7 of Set 6 | malakal
# Processing Record 8 of Set 6 | bulata
# Processing Record 9 of Set 6 | calbuco
# Processing Record 10 of Set 6 | dingle
# Processing Record 11 of Set 6 | miraflores
# Processing Record 12 of Set 6 | clearwater
# Processing Record 13 of Set 6 | kurilsk
# Processing Record 14 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 6 | miramar
# Processing Record 16 of Set 6 | bambous virieux
# Processing Record 17 of Set 6 | hasaki
# Processing Record 18 of Set 6 | qaqortoq
# Processing Record 19 of Set 6 | harlingen
# Processing Record 20 of Set 6 | kyren
# Processing Record 21 of Set 6 | rawson
# Processing Record 22 of Set 6 | gobabis
# Processing Record 23 of Set 6 | kieta
# Processing Record 24 of Set 6 | college
# Processing Record 25 of Set 6 | ous
# Processing Record 26 of Set 6 | tambacounda
# Processing Record 27 of Set 6 | norman wells
# Processing Record 28 of Set 6 | aswan
# Processing Record 29 of Set 6 | turukhansk
# Processing Record 30 of Set 6 | quatre cocos
# Processing Record 31 of Set 6 | luwuk
# Processing Record 32 of Set 6 | salamanca
# Processing Record 33 of Set 6 | rorvik
# Processing Record 34 of Set 6 | bani
# Processing Record 35 of Set 6 | mehamn
# Processing Record 36 of Set 6 | anadyr
# Processing Record 37 of Set 6 | grindavik
# Processing Record 38 of Set 6 | keene
# Processing Record 39 of Set 6 | klaksvik
# Processing Record 40 of Set 6 | orange cove
# Processing Record 41 of Set 6 | juruti
# Processing Record 42 of Set 6 | maues
# Processing Record 43 of Set 6 | borlange
# City not found. Skipping...
# Processing Record 44 of Set 6 | banda aceh
# Processing Record 45 of Set 6 | yakeshi
# Processing Record 46 of Set 6 | bereda
# Processing Record 47 of Set 6 | grand gaube
# Processing Record 48 of Set 6 | umm kaddadah
# Processing Record 49 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 50 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 7 | naze
# Processing Record 2 of Set 7 | monrovia
# Processing Record 3 of Set 7 | kahului
# Processing Record 4 of Set 7 | pachino
# Processing Record 5 of Set 7 | balkhash
# Processing Record 6 of Set 7 | fort smith
# Processing Record 7 of Set 7 | jumla
# Processing Record 8 of Set 7 | altoona
# Processing Record 9 of Set 7 | bikin
# Processing Record 10 of Set 7 | bubaque
# Processing Record 11 of Set 7 | richards bay
# Processing Record 12 of Set 7 | ambon
# Processing Record 13 of Set 7 | grand-santi
# Processing Record 14 of Set 7 | tabu
# Processing Record 15 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 7 | shenzhen
# Processing Record 17 of Set 7 | victoria
# Processing Record 18 of Set 7 | kokkinokhoma
# Processing Record 19 of Set 7 | mascote
# Processing Record 20 of Set 7 | ye
# City not found. Skipping...
# Processing Record 21 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 7 | honningsvag
# Processing Record 23 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 24 of Set 7 | tigil
# Processing Record 25 of Set 7 | athabasca
# Processing Record 26 of Set 7 | san patricio
# Processing Record 27 of Set 7 | neuquen
# Processing Record 28 of Set 7 | luganville
# Processing Record 29 of Set 7 | banjar
# Processing Record 30 of Set 7 | te anau
# Processing Record 31 of Set 7 | esna
# Processing Record 32 of Set 7 | paamiut
# Processing Record 33 of Set 7 | crib point
# Processing Record 34 of Set 7 | homer
# Processing Record 35 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 36 of Set 7 | sinjah
# City not found. Skipping...
# Processing Record 37 of Set 7 | iralaya
# Processing Record 38 of Set 7 | sao joao do piaui
# Processing Record 39 of Set 7 | zhaoqing
# Processing Record 40 of Set 7 | linxia
# Processing Record 41 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 7 | gualdo tadino
# Processing Record 43 of Set 7 | kargil
# Processing Record 44 of Set 7 | eyl
# Processing Record 45 of Set 7 | marv dasht
# City not found. Skipping...
# Processing Record 46 of Set 7 | rosetta
# Processing Record 47 of Set 7 | polyarnyy
# Processing Record 48 of Set 7 | tungkang
# City not found. Skipping...
# Processing Record 49 of Set 7 | aigle
# Processing Record 50 of Set 7 | dudinka
# Processing Record 1 of Set 8 | lowestoft
# Processing Record 2 of Set 8 | bay roberts
# Processing Record 3 of Set 8 | nioki
# Processing Record 4 of Set 8 | andevoranto
# City not found. Skipping...
# Processing Record 5 of Set 8 | nalgonda
# Processing Record 6 of Set 8 | mayumba
# Processing Record 7 of Set 8 | nome
# Processing Record 8 of Set 8 | zhigansk
# Processing Record 9 of Set 8 | pskov
# Processing Record 10 of Set 8 | praia da vitoria
# Processing Record 11 of Set 8 | georgiyevka
# Processing Record 12 of Set 8 | jacmel
# Processing Record 13 of Set 8 | san policarpo
# Processing Record 14 of Set 8 | cherskiy
# Processing Record 15 of Set 8 | isangel
# Processing Record 16 of Set 8 | port hardy
# Processing Record 17 of Set 8 | ostrovnoy
# Processing Record 18 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 19 of Set 8 | faanui
# Processing Record 20 of Set 8 | zaranj
# Processing Record 21 of Set 8 | marrakesh
# Processing Record 22 of Set 8 | los llanos de aridane
# Processing Record 23 of Set 8 | storforshei
# Processing Record 24 of Set 8 | kleck
# City not found. Skipping...
# Processing Record 25 of Set 8 | beatrice
# Processing Record 26 of Set 8 | gazojak
# Processing Record 27 of Set 8 | tilichiki
# Processing Record 28 of Set 8 | dunedin
# Processing Record 29 of Set 8 | sitka
# Processing Record 30 of Set 8 | opuwo
# Processing Record 31 of Set 8 | murray bridge
# Processing Record 32 of Set 8 | mandalgovi
# Processing Record 33 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 34 of Set 8 | norrtalje
# Processing Record 35 of Set 8 | guapo
# Processing Record 36 of Set 8 | khandbari
# Processing Record 37 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 38 of Set 8 | beringovskiy
# Processing Record 39 of Set 8 | batagay
# Processing Record 40 of Set 8 | nishihara
# Processing Record 41 of Set 8 | tecoanapa
# Processing Record 42 of Set 8 | broome
# Processing Record 43 of Set 8 | north bend
# Processing Record 44 of Set 8 | vila velha
# Processing Record 45 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 46 of Set 8 | kachikau
# City not found. Skipping...
# Processing Record 47 of Set 8 | thetford mines
# Processing Record 48 of Set 8 | sorong
# Processing Record 49 of Set 8 | pijijiapan
# Processing Record 50 of Set 8 | nanortalik
# Processing Record 1 of Set 9 | hirara
# Processing Record 2 of Set 9 | the valley
# Processing Record 3 of Set 9 | tempio pausania
# Processing Record 4 of Set 9 | sechura
# Processing Record 5 of Set 9 | navirai
# Processing Record 6 of Set 9 | longyearbyen
# Processing Record 7 of Set 9 | lebu
# Processing Record 8 of Set 9 | tuy hoa
# Processing Record 9 of Set 9 | mglin
# Processing Record 10 of Set 9 | collie
# Processing Record 11 of Set 9 | carlsbad
# Processing Record 12 of Set 9 | terrace
# Processing Record 13 of Set 9 | itarema
# Processing Record 14 of Set 9 | nantucket
# Processing Record 15 of Set 9 | bara
# Processing Record 16 of Set 9 | tongliao
# Processing Record 17 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 18 of Set 9 | nisia floresta
# Processing Record 19 of Set 9 | sirjan
# Processing Record 20 of Set 9 | touros
# Processing Record 21 of Set 9 | saltpond
# Processing Record 22 of Set 9 | jan kempdorp
# Processing Record 23 of Set 9 | sulangan
# Processing Record 24 of Set 9 | karratha
# Processing Record 25 of Set 9 | biak
# Processing Record 26 of Set 9 | van
# Processing Record 27 of Set 9 | podor
# Processing Record 28 of Set 9 | paranaiba
# Processing Record 29 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 30 of Set 9 | sao paulo de olivenca
# Processing Record 31 of Set 9 | beja
# Processing Record 32 of Set 9 | geraldton
# Processing Record 33 of Set 9 | antofagasta
# Processing Record 34 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 9 | gusau
# Processing Record 36 of Set 9 | flinders
# Processing Record 37 of Set 9 | salalah
# Processing Record 38 of Set 9 | bafoulabe
# Processing Record 39 of Set 9 | constitucion
# Processing Record 40 of Set 9 | provins
# Processing Record 41 of Set 9 | bethanien
# Processing Record 42 of Set 9 | lukuledi
# Processing Record 43 of Set 9 | puerto baquerizo moreno
# Processing Record 44 of Set 9 | tsabong
# Processing Record 45 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 46 of Set 9 | belmonte
# Processing Record 47 of Set 9 | kharan
# Processing Record 48 of Set 9 | shakawe
# Processing Record 49 of Set 9 | guerrero negro
# Processing Record 50 of Set 9 | takhtamygda
# Processing Record 1 of Set 10 | lyubeshiv
# City not found. Skipping...
# Processing Record 2 of Set 10 | marawi
# Processing Record 3 of Set 10 | sao joao da barra
# Processing Record 4 of Set 10 | valente
# Processing Record 5 of Set 10 | trincomalee
# Processing Record 6 of Set 10 | ginda
# Processing Record 7 of Set 10 | katsuura
# Processing Record 8 of Set 10 | ndjole
# Processing Record 9 of Set 10 | vestmannaeyjar
# Processing Record 10 of Set 10 | moorhead
# Processing Record 11 of Set 10 | bonavista
# Processing Record 12 of Set 10 | kushima
# Processing Record 13 of Set 10 | hoquiam
# Processing Record 14 of Set 10 | dingzhou
# Processing Record 15 of Set 10 | tahoua
# Processing Record 16 of Set 10 | teguise
# Processing Record 17 of Set 10 | novoagansk
# Processing Record 18 of Set 10 | san vicente de canete
# Processing Record 19 of Set 10 | lensk
# Processing Record 20 of Set 10 | srivardhan
# Processing Record 21 of Set 10 | fortuna
# Processing Record 22 of Set 10 | aksarka
# Processing Record 23 of Set 10 | balimo
# City not found. Skipping...
# Processing Record 24 of Set 10 | de aar
# Processing Record 25 of Set 10 | sovetskiy
# Processing Record 26 of Set 10 | rio pardo
# Processing Record 27 of Set 10 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 28 of Set 10 | port said
# Processing Record 29 of Set 10 | mutoko
# Processing Record 30 of Set 10 | dubno
# Processing Record 31 of Set 10 | dauphin
# Processing Record 32 of Set 10 | viedma
# Processing Record 33 of Set 10 | kigoma
# Processing Record 34 of Set 10 | patur
# Processing Record 35 of Set 10 | kununurra
# Processing Record 36 of Set 10 | waipawa
# Processing Record 37 of Set 10 | namibe
# Processing Record 38 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 10 | baruun-urt
# Processing Record 40 of Set 10 | savannah bight
# Processing Record 41 of Set 10 | valparaiso
# Processing Record 42 of Set 10 | comodoro rivadavia
# Processing Record 43 of Set 10 | champerico
# Processing Record 44 of Set 10 | novikovo
# Processing Record 45 of Set 10 | kenai
# Processing Record 46 of Set 10 | rafaela
# Processing Record 47 of Set 10 | susanville
# Processing Record 48 of Set 10 | morondava
# Processing Record 49 of Set 10 | tromso
# Processing Record 50 of Set 10 | erzin
# Processing Record 1 of Set 11 | kiruna
# Processing Record 2 of Set 11 | paidha
# Processing Record 3 of Set 11 | parati
# Processing Record 4 of Set 11 | prado
# Processing Record 5 of Set 11 | surin
# Processing Record 6 of Set 11 | estacion coahuila
# Processing Record 7 of Set 11 | filingue
# Processing Record 8 of Set 11 | toora-khem
# Processing Record 9 of Set 11 | verkhnevilyuysk
# Processing Record 10 of Set 11 | tautira
# Processing Record 11 of Set 11 | luderitz
# Processing Record 12 of Set 11 | meulaboh
# Processing Record 13 of Set 11 | ghansor
# Processing Record 14 of Set 11 | nikolayevka
# Processing Record 15 of Set 11 | kungurtug
# Processing Record 16 of Set 11 | shadegan
# Processing Record 17 of Set 11 | veraval
# Processing Record 18 of Set 11 | dosso
# Processing Record 19 of Set 11 | ewa beach
# Processing Record 20 of Set 11 | pisco
# Processing Record 21 of Set 11 | liepaja
# Processing Record 22 of Set 11 | milingimbi
# City not found. Skipping...
# Processing Record 23 of Set 11 | itoman
# Processing Record 24 of Set 11 | omboue
# Processing Record 25 of Set 11 | moree
# Processing Record 26 of Set 11 | zyryanka
# Processing Record 27 of Set 11 | quijingue
# Processing Record 28 of Set 11 | nchelenge
# Processing Record 29 of Set 11 | dobryanka
# Processing Record 30 of Set 11 | envira
# Processing Record 31 of Set 11 | shimoda
# Processing Record 32 of Set 11 | gizo
# Processing Record 33 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 34 of Set 11 | saint-paul
# Processing Record 35 of Set 11 | iquique
# Processing Record 36 of Set 11 | derzhavinsk
# Processing Record 37 of Set 11 | kailua
# Processing Record 38 of Set 11 | virginia beach
# Processing Record 39 of Set 11 | lorut
# Processing Record 40 of Set 11 | oranjestad
# Processing Record 41 of Set 11 | codrington
# Processing Record 42 of Set 11 | altay
# Processing Record 43 of Set 11 | masuguru
# Processing Record 44 of Set 11 | morgan city
# Processing Record 45 of Set 11 | rio gallegos
# Processing Record 46 of Set 11 | okmulgee
# Processing Record 47 of Set 11 | fort nelson
# Processing Record 48 of Set 11 | krasnyy kholm
# Processing Record 49 of Set 11 | rafiganj
# Processing Record 50 of Set 11 | ponta delgada
# Processing Record 1 of Set 12 | molochnoye
# Processing Record 2 of Set 12 | hofn
# Processing Record 3 of Set 12 | luangwa
# Processing Record 4 of Set 12 | fayaoue
# Processing Record 5 of Set 12 | cayhagan
# Processing Record 6 of Set 12 | waingapu
# Processing Record 7 of Set 12 | santa cruz
# Processing Record 8 of Set 12 | tazovskiy
# Processing Record 9 of Set 12 | along
# Processing Record 10 of Set 12 | camapua
# Processing Record 11 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 12 of Set 12 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 13 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 14 of Set 12 | samana
# Processing Record 15 of Set 12 | irsha
# Processing Record 16 of Set 12 | badulla
# Processing Record 17 of Set 12 | kirakira
# Processing Record 18 of Set 12 | toktogul
# Processing Record 19 of Set 12 | zhaozhou
# Processing Record 20 of Set 12 | dhing
# Processing Record 21 of Set 12 | camacha
# Processing Record 22 of Set 12 | tafresh
# Processing Record 23 of Set 12 | shiyan
# Processing Record 24 of Set 12 | emure
# Processing Record 25 of Set 12 | tanout
# Processing Record 26 of Set 12 | mpika
# Processing Record 27 of Set 12 | sao felix do xingu
# Processing Record 28 of Set 12 | moindou
# Processing Record 29 of Set 12 | ngunguru
# Processing Record 30 of Set 12 | bathsheba
# Processing Record 31 of Set 12 | arrah
# Processing Record 32 of Set 12 | pemberton
# Processing Record 33 of Set 12 | batagay-alyta
# Processing Record 34 of Set 12 | erenhot
# Processing Record 35 of Set 12 | srednekolymsk
# Processing Record 36 of Set 12 | mirnyy
# Processing Record 37 of Set 12 | kurkent
# Processing Record 38 of Set 12 | el tigre
# Processing Record 39 of Set 12 | correia pinto
# Processing Record 40 of Set 12 | chateaudun
# Processing Record 41 of Set 12 | ahipara
# Processing Record 42 of Set 12 | rudbar
# Processing Record 43 of Set 12 | novaya igirma
# Processing Record 44 of Set 12 | kudahuvadhoo
# Processing Record 45 of Set 12 | belaya gora
# Processing Record 46 of Set 12 | banepa
# Processing Record 47 of Set 12 | kaniama
# Processing Record 48 of Set 12 | tikhvin
# Processing Record 49 of Set 12 | lamar
# Processing Record 50 of Set 12 | svetlaya
# Processing Record 1 of Set 13 | linhares
# Processing Record 2 of Set 13 | sistranda
# Processing Record 3 of Set 13 | khandyga
# Processing Record 4 of Set 13 | wloclawek
# Processing Record 5 of Set 13 | namatanai
# Processing Record 6 of Set 13 | jibuti
# Processing Record 7 of Set 13 | qujing
# Processing Record 8 of Set 13 | hamilton
# Processing Record 9 of Set 13 | dalby
# Processing Record 10 of Set 13 | ca mau
# Processing Record 11 of Set 13 | jaunjelgava
# Processing Record 12 of Set 13 | mazagao
# Processing Record 13 of Set 13 | tocopilla
# Processing Record 14 of Set 13 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 15 of Set 13 | khoy
# Processing Record 16 of Set 13 | gebre guracha
# Processing Record 17 of Set 13 | imeni poliny osipenko
# Processing Record 18 of Set 13 | nabire
# Processing Record 19 of Set 13 | sheridan
# Processing Record 20 of Set 13 | ust-karsk
# Processing Record 21 of Set 13 | hargeysa
# Processing Record 22 of Set 13 | meybod
# Processing Record 23 of Set 13 | ugoofaaru
# Processing Record 24 of Set 13 | half moon bay
# Processing Record 25 of Set 13 | gasa
# Processing Record 26 of Set 13 | aitape
# Processing Record 27 of Set 13 | port moresby
# Processing Record 28 of Set 13 | chapais
# Processing Record 29 of Set 13 | parsons
# Processing Record 30 of Set 13 | atbasar
# Processing Record 31 of Set 13 | uarini
# Processing Record 32 of Set 13 | baykit
# Processing Record 33 of Set 13 | york
# Processing Record 34 of Set 13 | nueve de julio
# Processing Record 35 of Set 13 | konakovo
# Processing Record 36 of Set 13 | manado
# Processing Record 37 of Set 13 | kaspiysk
# Processing Record 38 of Set 13 | chiknayakanhalli
# Processing Record 39 of Set 13 | kimbe
# Processing Record 40 of Set 13 | zhuhai
# Processing Record 41 of Set 13 | kyakhta
# Processing Record 42 of Set 13 | carutapera
# Processing Record 43 of Set 13 | chara
# Processing Record 44 of Set 13 | hendijan
# City not found. Skipping...
# Processing Record 45 of Set 13 | povarovo
# Processing Record 46 of Set 13 | skibotn
# Processing Record 47 of Set 13 | middle island
# Processing Record 48 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 13 | vila
# Processing Record 50 of Set 13 | maceio
# Processing Record 1 of Set 14 | severnyy
# Processing Record 2 of Set 14 | shieli
# Processing Record 3 of Set 14 | olavarria
# Processing Record 4 of Set 14 | chifeng
# Processing Record 5 of Set 14 | anito
# Processing Record 6 of Set 14 | buala
# Processing Record 7 of Set 14 | zaysan
# Processing Record 8 of Set 14 | hami
# Processing Record 9 of Set 14 | ha tinh
# Processing Record 10 of Set 14 | phan thiet
# Processing Record 11 of Set 14 | nobeoka
# Processing Record 12 of Set 14 | yulara
# Processing Record 13 of Set 14 | rosario
# Processing Record 14 of Set 14 | roma
# Processing Record 15 of Set 14 | poum
# Processing Record 16 of Set 14 | carauari
# Processing Record 17 of Set 14 | soyaux
# Processing Record 18 of Set 14 | vryburg
# Processing Record 19 of Set 14 | haines junction
# Processing Record 20 of Set 14 | narasannapeta
# Processing Record 21 of Set 14 | praya
# Processing Record 22 of Set 14 | burnie
# Processing Record 23 of Set 14 | lakes entrance
# Processing Record 24 of Set 14 | malaya purga
# Processing Record 25 of Set 14 | tongren
# Processing Record 26 of Set 14 | strezhevoy
# Processing Record 27 of Set 14 | grimari
# City not found. Skipping...
# Processing Record 28 of Set 14 | awbari
# Processing Record 29 of Set 14 | pangnirtung
# Processing Record 30 of Set 14 | jiwani
# Processing Record 31 of Set 14 | shu
# Processing Record 32 of Set 14 | zachagansk
# City not found. Skipping...
# Processing Record 33 of Set 14 | gigmoto
# Processing Record 34 of Set 14 | preston
# Processing Record 35 of Set 14 | srikakulam
# Processing Record 36 of Set 14 | taltal
# Processing Record 37 of Set 14 | byron bay
# Processing Record 38 of Set 14 | seoul
# Processing Record 39 of Set 14 | tambopata
# Processing Record 40 of Set 14 | aracaju
# Processing Record 41 of Set 14 | gladstone
# Processing Record 42 of Set 14 | lekoni
# Processing Record 43 of Set 14 | flin flon
# Processing Record 44 of Set 14 | estelle
# Processing Record 45 of Set 14 | honiara
# Processing Record 46 of Set 14 | kadhan
# Processing Record 47 of Set 14 | nadym
# Processing Record 48 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 49 of Set 14 | uray
# Processing Record 50 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 1 of Set 15 | kricim
# City not found. Skipping...
# Processing Record 2 of Set 15 | wenling
# Processing Record 3 of Set 15 | mountain home
# Processing Record 4 of Set 15 | dinghai
# Processing Record 5 of Set 15 | skelleftea
# Processing Record 6 of Set 15 | huejuquilla el alto
# Processing Record 7 of Set 15 | kabwe
# Processing Record 8 of Set 15 | dalvik
# Processing Record 9 of Set 15 | waddan
# Processing Record 10 of Set 15 | ajdabiya
# Processing Record 11 of Set 15 | sobolevo
# Processing Record 12 of Set 15 | sigiriya
# Processing Record 13 of Set 15 | aksu
# Processing Record 14 of Set 15 | valencia
# Processing Record 15 of Set 15 | otradnoye
# Processing Record 16 of Set 15 | san clemente
# Processing Record 17 of Set 15 | ellisras
# Processing Record 18 of Set 15 | kingaroy
# Processing Record 19 of Set 15 | nerchinskiy zavod
# Processing Record 20 of Set 15 | sosva
# Processing Record 21 of Set 15 | avera
# Processing Record 22 of Set 15 | miranda
# Processing Record 23 of Set 15 | feira de santana
# Processing Record 24 of Set 15 | yambio
# Processing Record 25 of Set 15 | cap malheureux
# Processing Record 26 of Set 15 | talcahuano
# Processing Record 27 of Set 15 | zhengjiatun
# Processing Record 28 of Set 15 | roman
# Processing Record 29 of Set 15 | florence
# Processing Record 30 of Set 15 | yerbogachen
# Processing Record 31 of Set 15 | kaka
# Processing Record 32 of Set 15 | salinas
# Processing Record 33 of Set 15 | teguldet
# Processing Record 34 of Set 15 | brekstad
# Processing Record 35 of Set 15 | hobyo
# Processing Record 36 of Set 15 | sabang
# Processing Record 37 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 38 of Set 15 | zhezkazgan
# Processing Record 39 of Set 15 | tucurui
# Processing Record 40 of Set 15 | lorengau
# Processing Record 41 of Set 15 | bousse
# Processing Record 42 of Set 15 | faratsiho
# Processing Record 43 of Set 15 | catamarca
# Processing Record 44 of Set 15 | bairnsdale
# Processing Record 45 of Set 15 | ukiah
# Processing Record 46 of Set 15 | margate
# Processing Record 47 of Set 15 | kanniyakumari
# Processing Record 48 of Set 15 | niquelandia
# Processing Record 49 of Set 15 | marshall
# Processing Record 50 of Set 15 | vostok
# Processing Record 1 of Set 16 | jawhar
# Processing Record 2 of Set 16 | taoudenni
# Processing Record 3 of Set 16 | dzidzantun
# Processing Record 4 of Set 16 | lubango
# Processing Record 5 of Set 16 | spirovo
# Processing Record 6 of Set 16 | aljezur
# Processing Record 7 of Set 16 | elizabeth city
# Processing Record 8 of Set 16 | tres picos
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Confirm city count in the df again just to make sure I did it right 
len(city_data)
# Out:
# 694

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Henties Bay      NA -22.1160   14.2845     69.01        79           4
# 1    Fairbanks      US  64.8378 -147.7164     33.80       100          90
# 2     Ulaangom      MN  49.9811   92.0667     32.36        43           0
# 3      Ushuaia      AR -54.8000  -68.3000     44.60        65          20
# 4    Hithadhoo      MV  -0.6000   73.0833     83.82        74          75
# 5      Saravan      AM  39.7196   45.6483     51.80        46          40
# 6       Avarua      CK -21.2078 -159.7750     80.60        83          75
# 7      Rikitea      PF -23.1203 -134.9692     76.77        70          26
# 8      Qaanaaq      GL  77.4840  -69.3632    -12.46        68          17
# 9       Albany      US  42.6001  -73.9662     54.00        20          30
#
#    Wind Speed Current Description
# 0       10.00           clear sky
# 1        5.75          light rain
# 2        2.04           clear sky
# 3        8.05          few clouds
# 4       17.34       broken clouds
# 5        4.61    scattered clouds
# 6       11.50       broken clouds
# 7       14.70          light rain
# 8        6.96          few clouds
# 9        1.01    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
